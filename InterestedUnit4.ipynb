# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek-AIML/25f1000001_git_challenge_lab/blob/main/InterestedUnit4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Week 4 - Exercise 3

def find_min(items:list):
  return min(items)


items = [2, 3, 4, 1, -1, 5]  # First Function
print("Min", end='#')
print(find_min(items))

def odd_square_even_double_modify(items:list) -> list:
  mList = [item ** 2 if item % 2 == 1 else
           item * 2 if item % 2 ==0 else
           None
           for item in items]
  return mList

item = [2, 3, 4, 1, -1, 5]
mlistOut = odd_square_even_double_modify(item)
print("Odd Square even Double", end='#')
print(mlistOut)




#odd_square_even_double_modify: Square all the odd numbers and double all the even numbers in a list, modifying the list in place.
#Input: A list of integers.
#Output: None (the input list is modified in place).

def odd_square_even_double_modify(items:list) -> list:

  mList = [item * 2 if item % 2 == 1 else
           item ** 2 if item % 2 == 0 else
           None
           for item in items]


def more_than_two_unique_vowels(sentence):
  sentence = sentence.lower()
  vowels = 'aeiou'

  result = set()

  for word in sentence.split() :
    unique_vowels = { ch for ch in word if ch in vowels}
    if (len(unique_vowels) > 2) :
      result.add(word)  # because ask is that it will return a set and not list
  return result             # set doesn't have apppend and insert functionality

more_than_two_unique_vowels("functions are not complicated")


def sum_of_all_the_list_items(lol):
  sumItems = 0
  for sublist in lol:
    sumItems += sum(sublist)
  return sumItems

# Correcting the function call to pass a single list of lists
sum_of_all_the_list_items([[2, 4, 6, 8], [1, 3, 4, 5], [6, 7, 8, 9]])
# Out:
# Min#-1
# Odd Square even Double#[4, 9, 8, 1, 1, 25]
# 63
